# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns

# %%
dfes = pd.read_csv('RiverRoad_Quan_RF.csv')

# %%
dfes = dfes[dfes['wetland']=='wetland']

# %%
df_corr = pd.concat([dfes[dfes.columns[1:62]], dfes['FID_RiverRd_AOI']], axis=1)
corr = df_corr.corr()
df_corr = pd.DataFrame(corr['FID_RiverRd_AOI'])

df_corr = df_corr[:-1]
df_corr
# Out:
#                  FID_RiverRd_AOI
# qu_dem_MIN                   NaN
# qu_dem_MAX                   NaN
# qu_dem_RANGE                 NaN
# qu_dem_MEAN                  NaN
# qu_dem_STD                   NaN
# qu_dem_SUM                   NaN
# qu_dsm_MIN                   NaN
# qu_dsm_MAX                   NaN
# qu_dsm_RANGE                 NaN
# qu_dsm_MEAN                  NaN
# qu_dsm_STD                   NaN
# qu_dsm_SUM                   NaN
# qu_hyddem_MIN                NaN
# qu_hyddem_MAX                NaN
# qu_hyddem_RANGE              NaN
# qu_hyddem_MEAN               NaN
# qu_hyddem_STD                NaN
# qu_hyddem_SUM                NaN
# qu_smdem_MIN                 NaN
# qu_smdem_MAX                 NaN
# qu_smdem_RANGE               NaN
# qu_smdem_MEAN                NaN
# qu_smdem_STD                 NaN
# qu_smdem_SUM                 NaN
# qu_asp_MIN                   NaN
# qu_asp_MAX                   NaN
# qu_asp_RANGE                 NaN
# ...

# %%
sns.lmplot(data=dfes, x="qu_dem_MEAN", y="qu_dsm_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dem_MEAN", y="qu_hyddem_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dem_MEAN", y="qu_smdem_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dem_MEAN", y="qu_asp_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dem_MEAN", y="qu_floAcu_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dem_MEAN", y="qu_floDir_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dem_MEAN", y="qu_curv_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dem_MEAN", y="qu_curpl_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dem_MEAN", y="qu_curpr_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dsm_MEAN", y="qu_hyddem_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dsm_MEAN", y="qu_smdem_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dsm_MEAN", y="qu_asp_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dsm_MEAN", y="qu_floAcu_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dsm_MEAN", y="qu_floDir_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dsm_MEAN", y="qu_curv_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dsm_MEAN", y="qu_curpl_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_dsm_MEAN", y="qu_curpr_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_hyddem_MEAN", y="qu_smdem_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_hyddem_MEAN", y="qu_asp_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_hyddem_MEAN", y="qu_floAcu_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_hyddem_MEAN", y="qu_floDir_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_hyddem_MEAN", y="qu_curv_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_hyddem_MEAN", y="qu_curpl_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_hyddem_MEAN", y="qu_curpr_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_smdem_MEAN", y="qu_asp_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_smdem_MEAN", y="qu_floAcu_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_smdem_MEAN", y="qu_floDir_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_smdem_MEAN", y="qu_curv_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_smdem_MEAN", y="qu_curpl_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_smdem_MEAN", y="qu_curpr_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_asp_MEAN", y="qu_floAcu_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_asp_MEAN", y="qu_floDir_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_asp_MEAN", y="qu_curv_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_asp_MEAN", y="qu_curpl_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_asp_MEAN", y="qu_curpr_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_floAcu_MEAN", y="qu_floDir_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_asp_MEAN", y="qu_curv_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_asp_MEAN", y="qu_curpl_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_asp_MEAN", y="qu_curpr_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_floAcu_MEAN", y="qu_floDir_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_floAcu_MEAN", y="qu_curv_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_floAcu_MEAN", y="qu_curpl_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_floAcu_MEAN", y="qu_curpr_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_floDir_MEAN", y="qu_curv_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_floDir_MEAN", y="qu_curv_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_floDir_MEAN", y="qu_curpl_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_floDir_MEAN", y="qu_curpr_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_floDir_MEAN", y="qu_curv_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_floDir_MEAN", y="qu_curpl_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_floDir_MEAN", y="qu_curpr_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_curv_MEAN", y="qu_curpl_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_curv_MEAN", y="qu_curpr_MEAN", hue="wetland_type")

# %%
sns.lmplot(data=dfes, x="qu_curpl_MEAN", y="qu_curpr_MEAN", hue="wetland_type")
