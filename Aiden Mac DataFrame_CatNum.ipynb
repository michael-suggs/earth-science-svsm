# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns

# %%
dfes = pd.read_csv('RiverRoad_Quan_RF.csv')
qu_dem = dfes[dfes.columns[1:7]]
qu_dsm = dfes[dfes.columns[7:13]]
qu_hyddem = dfes[dfes.columns[13:19]]
qu_smdem = dfes[dfes.columns[19:25]]
qu_asp = dfes[dfes.columns[25:31]]
qu_floAcu = dfes[dfes.columns[31:37]]
qu_floDir = dfes[dfes.columns[37:43]]
qu_curv = dfes[dfes.columns[43:49]]
qu_curpl = dfes[dfes.columns[49:55]]
qu_curpr = dfes[dfes.columns[55:61]]

# %%
sns.set_theme(style="ticks", color_codes=True)


compare_data = qu_curv #Put the variable you wish to compare here. 

column_num = 0

loop = True

while loop == True:
    if column_num == 6:
        loop = False
    else:
        y = compare_data[compare_data.columns[column_num]]
        sns.catplot(x='wetland', y=y, data=dfes)
        column_num += 1
